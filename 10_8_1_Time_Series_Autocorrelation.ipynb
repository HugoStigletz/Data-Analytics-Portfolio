# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoStigletz/Data-Analytics-Portfolio/blob/main/10_8_1_Time_Series_Autocorrelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lesson 11.8.1 Activity
#
# In this activity, we’ll examine trends in the daily low temperature measured in Melbourne, Australia from 1981 to 1990.  We’ll determine if there is autocorrelation present in the data and begin to model the relationship of temperature over time.

# %% [markdown]
# #Step 1: Download and save the `daily-min-temperatures.csv` dataset from the class materials
#
# * Make a note of where you saved the file on your computer.

# %% [markdown]
# #Step 2: Upload the `daily-min-temperatures.csv` dataset by running the following code block
#
# * When prompted, navigate to and select the `daily-min-temperatures.csv` dataset where you saved it on your computer.

# %%
#Step 2

'''from google.colab import files
temperatures = files.upload()'''

# %% [markdown]
# #Step 3: Import necessary packages
#
# ```
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from pandas.plotting import lag_plot, autocorrelation_plot
# from statsmodels.graphics.tsaplots import plot_acf

# %%
#Step 3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot, autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf

# %% [markdown]
# # Step 4: Create a Pandas DataFrame from the CSV file
# * Name the DataFrame `temperatures`.
# * In the `pd._read_csv` statement, add the arguments `header=0, index_col=0`.  This tells Python to use the date column as the index and that the column names are specified in the first row.
# * Print the first five observations of `temperatures`.  Note the kinds of data it contains.

# %%
#Step 4
temperatures = pd.read_csv('/daily-min-temperatures.csv', header=0, index_col=0)

temperatures
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %% [markdown]
# #Step 5: Plot the temperature data over time.
# * Run the following code block to visualize the daily low temperature in Melbourne, AU from 1981 to 1990.
# * What do you notice about when the highest and lowest daily low temperatures occur?  Note: This might be different than you are used to if you've always lived in the northern hemisphere.

# %%
#Step 5

temperatures.plot()
plt.rcParams["figure.figsize"] = [12, 12]
plt.ylabel('Daily Minimum Temperature in C')
plt.title('Daily Mimimum Temperature in Melbourne, Australia: 1981 - 1990')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Step 5 Answer:**

# %% [markdown]
# #Step 6: Plot the autocorrelation of the temperature each day with the temperature the day before.
# * Run the following code block to visualize the relationship of the daily low temperature in Melbourne, Australia with the temperature the day before.
# * Do the two appear highly correlated?  That is, do they appear to be closely related?

# %%
#Step 6

lag_plot(temperatures)
plt.ylabel('Previous Day Daily Minimum Temperature in C')
plt.xlabel('Daily Minimum Temperature in C')
plt.title('Autocorrelation of Daily Mimimum Temperature in Melbourne, Australia: 1981 - 1990')
plt.show()

# %% [markdown]
# **Step 6 Answer:**

# %% [markdown]
# #Step 7: Plot the autocorrleation over a longer period of time.
# * Run the following code block to calculate the autocorrelation between the current temperature and all previous temperatures.
# * Recall that correlation can take on any value between -1 and +1.  A correlation near -1 indicates a strong negative relationship between the two measures.  A correltion near +1 indicates a strong positive relationship.  A correlation near 0 indicates no relationship.
# * Look at the temperature within the first 500 days.  Why does the correlation start strong and positive, become weak, become strong and negative, become weak, and then become strong and positive again?

# %%
#Step 7

autocorrelation_plot(temperatures)
plt.show()
'''fig = plt.figure(figsize=[30,30])'''
# Out:
# 'fig = plt.figure(figsize=[30,30])'

# %% [markdown]
# **Step 7 Answer:**

# %% [markdown]
# #Step 8: Increasing lag
# * After how many days of lag does the correlation never get stronger than +0.25 or -0.25?

# %% [markdown]
# **Step 8 Answer:**

# %% [markdown]
# #Step 9: Autocorrelation close up
# * Run the following code block to visualize the correlation of the current daily temperature with the temperatures for the current plus previous 30 days.
# * What is the approximate correlation of the daily temperature with the temperature the day before?
# * What is the approximate correlation of the daily temperature with the temperature two days before?

# %%
#Step 9

plot_acf(temperatures, lags=31)
plt.show()

# %% [markdown]
# **Step 9 Answer:**
