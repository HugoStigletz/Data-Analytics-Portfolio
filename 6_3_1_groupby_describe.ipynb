# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoStigletz/Data-Analytics-Portfolio/blob/main/6_3_1_groupby_describe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Exploration
#
# `Data Exploration` is the first step in any data wrangling process and allows us to familiarize ourselves with the data as well as create a possible plan of action going forward.
#
# It is important to ask ourselves a few questions as we look at a new dataset:
# - What data types are present?
# - How large is this dataset?
# - What questions can this data answer?
# - Which tools would best lend themselves to this data?

# %% [markdown]
# ## Absenteeism at Work
# Let's explore the Absenteeism at Work dataset using the .describe() and groupby methods.
#
# You can find the data source in the [UCI Machine Learning Library](https://archive.ics.uci.edu/ml/datasets/Absenteeism+at+work) along with additional information about what each element represents.
#
# Note: The data that provides information on other data is referred to as `metadata`.

# %% [markdown]
# ### Step 1: Upload data

# %%
from google.colab import files
absenteeism = files.upload()
# Out:
#      <input type="file" id="files-f0617c0c-6add-45f6-ae38-24ed2794190b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0617c0c-6add-45f6-ae38-24ed2794190b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving absenteeism.csv to absenteeism.csv

# %% [markdown]
# ### Step 2: Import libraries and read csv as a dataframe
# * Make sure to use pd.read_csv('Absenteeism_at_work', sep=';') because the data is semicolon separated.

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/6.3.1 absenteeism.csv', sep = ',')

# %% [markdown]
# ### Step 3: How large is the dataset?
#
# Use dataframe.shape to get the (# columns, # rows)

# %%
df1.shape
# Out:
# (740, 21)

# %% [markdown]
# ### Step 4: Display the first 10 rows

# %%
df1.head(10)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
# 5   3                  23                 7                6        1
# 6  10                  22                 7                6        1
# 7  20                  23                 7                6        1
# 8  14                  19                 7                2        1
# 9   1                  22                 7                2        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
# 5                     179                               51            18   38
# 6                     361                               52             3   28
# 7                     260                               50            11   36
# 8                     155                               12            14   34
# 9                     235                               11            14   37
#
#    Work load Average/day  ...  Disciplinary failure  Education  Son  \
# 0                239.554  ...                     0          1    2
# 1                239.554  ...                     1          1    1
# 2                239.554  ...                     0          1    0
# 3                239.554  ...                     0          1    2
# 4                239.554  ...                     0          1    2
# 5                239.554  ...                     0          1    0
# 6                239.554  ...                     0          1    1
# 7                239.554  ...                     0          1    4
# 8                239.554  ...                     0          1    2
# 9                239.554  ...                     0          3    1
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0               1              0    1      90     172               30
# 1               1              0    0      98     178               31
# 2               1              0    0      89     170               31
# 3               1              1    0      68     168               24
# 4               1              0    1      90     172               30
# 5               1              0    0      89     170               31
# 6               1              0    4      80     172               27
# 7               1              0    0      65     168               23
# 8               1              0    0      95     196               25
# 9               0              0    1      88     172               29
#
#    Absenteeism time in hours
# 0                          4
# 1                          0
# 2                          2
# 3                          4
# 4                          2
# 5                          2
# 6                          8
# 7                          4
# 8                         40
# 9                          8
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Step 5: What are the data types?

# %%
# Run .dtypes on the dataframe to see the data types
df1.dtypes
# Out:
# ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %% [markdown]
# ### Step 6: Describe
#
# Use .describe() in the code cell below to see an overview of numeric data.

# %%
df1.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      4.000000              260.000000                        50.000000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day  ...  \
# count    740.000000  740.000000             740.000000  ...
# mean      12.554054   36.450000             271.490235  ...
# std        4.384873    6.478772              39.058116  ...
# min        1.000000   27.000000             205.917000  ...
# 25%        9.000000   31.000000             244.387000  ...
# 50%       13.000000   37.000000             264.249000  ...
# 75%       16.000000   40.000000             294.217000  ...
# max       29.000000   58.000000             378.884000  ...
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            740.000000  740.000000  740.000000      740.000000
# mean               0.054054    1.291892    1.018919        0.567568
# std                0.226277    0.673238    1.098489        0.495749
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     740.000000  740.000000  740.000000  740.000000       740.000000
# mean        0.072973    0.745946   79.035135  172.114865        26.677027
# std         0.260268    1.318258   12.883211    6.034995         4.285452
# min         0.000000    0.000000   56.000000  163.000000        19.000000
# 25%         0.000000    0.000000   69.000000  169.000000        24.000000
# 50%         0.000000    0.000000   83.000000  170.000000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 740.000000
# mean                    6.924324
# std                    13.330998
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000
#
# [8 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df1.plot(x = '...', y = '...')

# %% [markdown]
# ### Step 7: Group by
#
# Based on the first 10 rows, we see that some of the ID column numbers are duplicates. This probably means that each row is an absence and each ID is an employee. If we want to see all the absences for each employee, we will need to group by ID.
#
# Use groupby on ID and return the sum of `Abesnteeism time in hours` for each ID.

# %% [markdown]
# ----------Predict the absenteeism
# rate amongst employees
# based on a variety of factors:-------------

# %%
df1.groupby('ID').agg({'Absenteeism time in hours': ['count','sum']})

#df1.groupby('ID').agg({'Absenteeism time in hours': 'sum'})

#df1.groupby('ID').agg({'Distance from Residence to Work': 'sum'})

# %%
#df1.groupby('ID').agg({'Absenteeism time in hours': 'sum'}).sort_values(
#    "Absenteeism time in hours", ascending= False)

df1.groupby('ID').agg({'Absenteeism time in hours': 'sum'}).sort_values(
    "Absenteeism time in hours", ascending= False).reset_index()
    # .rest_index() is adding the primary key index

# %% [markdown]
# Congratulations! Now you have practice exploring a dataset. These are just some possible data exploration techniques, feel free to continue exploring this dataset in the cells below.

# %%
df1.groupby('ID').size()
# Out:
# ID
# 1      23
# 2       6
# 3     113
# 4       1
# 5      19
# 6       8
# 7       6
# 8       2
# 9       8
# 10     24
# 11     40
# 12      7
# 13     15
# 14     29
# 15     37
# 16      2
# 17     20
# 18     16
# 19      3
# 20     42
# 21      3
# 22     46
# 23      8
# 24     30
# 25     10
# 26      5
# 27      7
# 28     76
# 29      5
# 30      7
# 31      3
# 32      5
# 33     24
# 34     55
# 35      1
# 36     34
# dtype: int64
