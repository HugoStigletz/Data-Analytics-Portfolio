# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoStigletz/Data-Analytics-Portfolio/blob/main/fast_scraper_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

scraper = pd.read_html("https://en.wikipedia.org/wiki/Comparison_of_Linux_distributions")

# scraper (For a complete scrap of the URL)

for idx, table in enumerate(scraper):
    print("************************************************")
    print(idx)
    print(table)
    # Look for the Distribution table under index 3 and run that in the following code
# Out:
# ************************************************
# 0
#     0                                                  1
# 0 NaN  This article has multiple issues. Please help ...
# 1 NaN  This article needs to be updated. The reason g...
# 2 NaN  This article may require cleanup to meet Wikip...
# ************************************************
# 1
#     0                                                  1
# 0 NaN  This article needs to be updated. The reason g...
# ************************************************
# 2
#     0                                                  1
# 0 NaN  This article may require cleanup to meet Wikip...
# ************************************************
# 3
#     Distribution                  Founder                     Maintainer  \
# 0      AlmaLinux     AlmaLinux Foundation           AlmaLinux Foundation
# 1   Alpine Linux        Alpine Linux Team              Alpine Linux Team
# 2      ALT Linux           ALT Linux Team  ALT Linux Team, ALT Linux LLC
# ...

# %%
scraper[3]
# Out:
#     Distribution                  Founder                     Maintainer  \
# 0      AlmaLinux     AlmaLinux Foundation           AlmaLinux Foundation
# 1   Alpine Linux        Alpine Linux Team              Alpine Linux Team
# 2      ALT Linux           ALT Linux Team  ALT Linux Team, ALT Linux LLC
# 3          antiX          Anticapitalista                Anticapitalista
# 4       ArchBang       Willensky Aristide                   Stan McLaren
# ..           ...                      ...                            ...
# 94       Xandros     Xandros Incorporated           Xandros Incorporated
# 95       Zentyal        eBox Technologies              eBox Technologies
# 96       Zenwalk  Jean-Philippe Guillemin                       dev team
# 97      Zorin OS              Zorin Group                    Zorin Group
# 98  Distribution                  Founder                     Maintainer
#
#     Initial release year  Current stable version  Security updates (years)  \
# ...
