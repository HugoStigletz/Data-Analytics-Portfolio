# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoStigletz/Data-Analytics-Portfolio/blob/main/6_6_2_Datetime_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6.6.2 Activity: Python Packages and Libraries
# You are an environmental scientist tasked by the governor of California to show maps of California and to show the extreme fire season during the summer. Make a copy of this notebook and work through it in your own Drive.

# %% [markdown]
# ### Step 1: Make sure you have `CA_wildfires.csv` downloaded and upload here.

# %%
from google.colab import files
CA_wildfires = files.upload()

# %% [markdown]
# ### Step 2: Import packages and libraries and load data into dataframe.
# There is no "date" column in a format that is easy to read. However, we do have the fire year, and the discover day of the year as `DISCOVERY_DOY`

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import folium


fires = pd.read_csv('/content/6.6.2 & 6.6.3 CA_wildfires.csv')
fires.head()
# Out:
#          SOURCE_REPORTING_UNIT_NAME  FIRE_YEAR  FIRE_SIZE   LONGITUDE  \
# 0          Eldorado National Forest       2004        0.1 -119.913333
# 1          Eldorado National Forest       2004        0.1 -119.933056
# 2          Eldorado National Forest       2004    16823.0 -120.211667
# 3          Eldorado National Forest       2004     7700.0 -120.260000
# 4  Humboldt-Toiyabe National Forest       2005        0.1 -119.840556
#
#     LATITUDE  DISCOVERY_DATE  DISCOVERY_DOY  DISCOVERY_TIME  STAT_CAUSE_CODE  \
# 0  38.559167       2453184.5            180          1600.0                1
# 1  38.559167       2453184.5            180          1600.0                1
# 2  38.523333       2453284.5            280          1415.0                2
# 3  38.780000       2453291.5            287          1618.0                2
# 4  38.700278       2453496.5            126          1145.0                5
#
#   STAT_CAUSE_DESCR  CONT_DATE  CONT_DOY  CONT_TIME       OWNER_DESCR STATE  \
# 0        Lightning  2453189.5     185.0     1400.0              USFS    CA
# 1        Lightning  2453189.5     185.0     1200.0              USFS    CA
# 2    Equipment Use  2453299.5     295.0     1000.0              USFS    CA
# 3    Equipment Use  2453295.5     291.0     1800.0              USFS    CA
# 4   Debris Burning  2453499.5     129.0     1330.0  STATE OR PRIVATE    CA
#
#   COUNTY
# 0    3.0
# 1    3.0
# 2    5.0
# 3   17.0
# 4    3.0

# %%
fires.shape, fires.columns
# Out:
# ((5774, 16),
#  Index(['SOURCE_REPORTING_UNIT_NAME', 'FIRE_YEAR', 'FIRE_SIZE', 'LONGITUDE',
#         'LATITUDE', 'DISCOVERY_DATE', 'DISCOVERY_DOY', 'DISCOVERY_TIME',
#         'STAT_CAUSE_CODE', 'STAT_CAUSE_DESCR', 'CONT_DATE', 'CONT_DOY',
#         'CONT_TIME', 'OWNER_DESCR', 'STATE', 'COUNTY'],
#        dtype='object'))

# %% [markdown]
# #### Step 3: Use `pd.to_datetime`
# The data set provides the fire year along with the day of the year the fire was discovered. One way to get the column in the right format is by using some handy arithmetic.
#
# **Hint:** Python can take a date written in the form YYYYDOY and turn it into a datetime. So, for example, if it was January 15, 2015, it could turn 2015015 into the correct datetime.

# %%
#First, save the column as a series of the dataframe in the right YYYYDOY format.
year_doy = ...

# %%
#First 
year_doy = fires['FIRE_YEAR'] * 1000 + fires['DISCOVERY_DOY']

# %%
## 2004 "yr" + 180 days of the year | how many days of the year so far
year_doy
# Out:
# 0       2004180
# 1       2004180
# 2       2004280
# 3       2004287
# 4       2005126
#          ...
# 5769    2010206
# 5770    2014157
# 5771    2014184
# 5772    2015210
# 5773    2015213
# Length: 5774, dtype: int64

# %% [markdown]
# #### Now use datetime to add a 'Date' column.
#
# For reference, here is the [format documentation](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes).

# %%
#key
fires['Date'] = pd.to_datetime(year_doy, format='%Y%j')

# %%
fires['Date']
# Out:
# 0      2004-06-28
# 1      2004-06-28
# 2      2004-10-06
# 3      2004-10-13
# 4      2005-05-06
#           ...
# 5769   2010-07-25
# 5770   2014-06-06
# 5771   2014-07-03
# 5772   2015-07-29
# 5773   2015-08-01
# Name: Date, Length: 5774, dtype: datetime64[ns]

# %% [markdown]
# ### Step 4: Now that we have a date column, we can visualize the California fires on different dates.

# %%
#Filter rows/columns for the map. Start by selecting the year, fire size, and long/lat.
fires_map = fires[['FIRE_YEAR', 'FIRE_SIZE', 'LONGITUDE', 'LATITUDE', 'COUNTY', 'STATE', 'Date']]

# %%
#Let's just look at the 2015 fires that were larger than 3000 acres.
fires_map2 = fires_map[(fires_map['Date'].dt.year == 2015) & (fires_map['FIRE_SIZE'] > 3000) & (fires_map['STATE'] == 'CA')]

# %%
fires_map.head()
# Out:
#    FIRE_YEAR  FIRE_SIZE   LONGITUDE   LATITUDE COUNTY STATE       Date
# 0       2004        0.1 -119.913333  38.559167    3.0    CA 2004-06-28
# 1       2004        0.1 -119.933056  38.559167    3.0    CA 2004-06-28
# 2       2004    16823.0 -120.211667  38.523333    5.0    CA 2004-10-06
# 3       2004     7700.0 -120.260000  38.780000   17.0    CA 2004-10-13
# 4       2005        0.1 -119.840556  38.700278    3.0    CA 2005-05-06

# %%
fires_map2.head()
# Out:
#       FIRE_YEAR  FIRE_SIZE   LONGITUDE   LATITUDE COUNTY STATE       Date
# 5360       2015     4812.0 -121.391667  41.398333    049    CA 2015-07-30
# 5369       2015    12166.0 -123.775833  41.555833    015    CA 2015-08-02
# 5370       2015     6797.8 -123.453333  40.956944    023    CA 2015-07-30
# 5380       2015     6960.0 -118.535556  36.235278    107    CA 2015-07-19
# 5448       2015     3676.0 -119.159167  37.878056    051    CA 2015-08-14

# %%
#Create an empty map
m = folium.Map(location=[37.76, -122.45], tiles = 'Stamen Terrain', zoom_start=6)

#Add the bubbles
for i in range(0,len(fires_map2)):
   folium.Circle(
      location=[fires_map2.iloc[i]['LATITUDE'], fires_map2.iloc[i]['LONGITUDE']],
      radius=float(fires_map2.iloc[i]['FIRE_SIZE']),
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_a86989c9996c697f0d51c6d8313ee7f4 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_a86989c9996c697f0d51c6d8313ee7f4&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_a86989c9996c697f0d51c6d8313ee7f4 = L.map(
#         &#x27;map_a86989c9996c697f0d51c6d8313ee7f4&#x27;, {
#         center: [37.76, -122.45],
#         zoom: 6,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_60426616f84c1496ffe735009150a6e5 = L.tileLayer(
#         &#x27;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_a86989c9996c697f0d51c6d8313ee7f4);
#
#
#             var circle_9f987f73c6750b87f607730a1277ce14 = L.circle(
#                 [41.39833333, -121.39166667],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 4812.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_a86989c9996c697f0d51c6d8313ee7f4);
#
#
#
#             var circle_fe3c345aa5ce7ebbb2607097ed28336e = L.circle(
#                 [41.55583333, -123.77583333],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 12166.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_a86989c9996c697f0d51c6d8313ee7f4);
#
#
#
#             var circle_101061faf80009163d2b535b8cd5c7f9 = L.circle(
#                 [40.95694444, -123.45333333],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 6797.8,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_a86989c9996c697f0d51c6d8313ee7f4);
#
#
#
#             var circle_e3ca586d7652c1a8207acf07b938a605 = L.circle(
#                 [36.23527778, -118.53555556],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 6960.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_a86989c9996c697f0d51c6d8313ee7f4);
#
#
#
#             var circle_143d79e00deaf6f9ec53cde9b1d6f2fe = L.circle(
#                 [37.87805556, -119.15916667],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 3676.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_a86989c9996c697f0d51c6d8313ee7f4);
#
#
#
#             var circle_2e1eaa8fd75879cb3d5ab9bca35e870b = L.circle(
#                 [40.3575, -123.44138889],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 8299.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_a86989c9996c697f0d51c6d8313ee7f4);
#
#
#
#             var circle_d2f489f9dfab8abd2cb692f1845a9484 = L.circle(
#                 [40.89861111, -123.46138889],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,

# %% [markdown]
# ### Step 5: Replace the `...` with the year you want to explore.

# %%
#Replace ellipsis
fires_map3 = fires_map[(fires_map['Date'].dt.year == 2000) & (fires_map['FIRE_SIZE'] > 3000)]

#Create an empty map
n = folium.Map(location=[37.76, -122.45], tiles = 'Stamen Terrain', zoom_start=6)

#Add the bubbles
for i in range(0,len(fires_map3)):
    folium.Circle(
      location=[fires_map3.iloc[i]['LATITUDE'], fires_map3.iloc[i]['LONGITUDE']],
      radius=float(fires_map3.iloc[i]['FIRE_SIZE']),
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(n)
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_7f5570f09f74da3f12926901e67161a2 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_7f5570f09f74da3f12926901e67161a2&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_7f5570f09f74da3f12926901e67161a2 = L.map(
#         &#x27;map_7f5570f09f74da3f12926901e67161a2&#x27;, {
#         center: [37.76, -122.45],
#         zoom: 6,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_3169894eddd91f3ccc07f46eb5477088 = L.tileLayer(
#         &#x27;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_7f5570f09f74da3f12926901e67161a2);
#
#
#             var circle_c0ccc79bea0d9f8304a7687ff386f6a1 = L.circle(
#                 [35.93027778, -121.43333333],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5856.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7f5570f09f74da3f12926901e67161a2);
#
#
#
#             var circle_df401447c269fad783d951cbbb4ad623 = L.circle(
#                 [35.86777778, -118.28388889],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 75000.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7f5570f09f74da3f12926901e67161a2);
#
#
#
#             var circle_c2da82e9437edcbdc9c15b45b562b694 = L.circle(
#                 [39.91694444, -121.3175],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 55261.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7f5570f09f74da3f12926901e67161a2);
#
#
#
#             var circle_5bf73835fb2324bbb932438c145d2810 = L.circle(
#                 [37.6166, -120.2177],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 8600.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7f5570f09f74da3f12926901e67161a2);
#
#
#
#             var circle_f69087b6726d655b141d3e97c29ee031 = L.circle(
#                 [38.9182, -122.6994],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 3283.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7f5570f09f74da3f12926901e67161a2);
#
#
#
#             var circle_9a30ba971fcb5446c0000bec9865b089 = L.circle(
#                 [39.9665, -122.6094],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;crimson&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 8284.0,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7f5570f09f74da3f12926901e67161a2);
#
#
#
#             var circle_a29d97633384f63768dd40861fc0b407 = L.circle(
#                 [36.0713, -117.107],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;crimson&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot

# %% [markdown]
# ### Conclusions
# What do you notice about the locations of the large fires?
#
# **Double-click and replace this text to answer.**

# %%
fires_map.dtypes
# Out:
# FIRE_YEAR             int64
# FIRE_SIZE           float64
# LONGITUDE           float64
# LATITUDE            float64
# COUNTY               object
# STATE                object
# Date         datetime64[ns]
# dtype: object

# %%
from datetime import datetime, timedelta, date

# %%
# df['dates'] = pd.to_datetime(df['dates'])

# %%
from datetime import datetime
strs = '21 September,2021'
datetime.strptime(strs, '%d %B,%Y')
# Out:
# datetime.datetime(2021, 9, 21, 0, 0)

# %%
strs = "21 September, 2021"                       ## string
dtime = datetime.strptime(strs, "%d %B, %Y")     ## convert string to date
strdate = datetime.isoformat(dtime)              ## convert to ISO format

strdate
# Out:
# '2021-09-21T00:00:00'

# %%
strs = "21 September, 2021"                       ## string
dtime = datetime.strptime(strs, "%d %B, %Y") ## convert string to date

ddate = dtime.date()               ## extract the date portion
date.isoformat(ddate)              ## convert to ISO format
# Out:
# '2021-09-21'

# %%
pd.to_datetime('7/12/2021', format='%m/%d/%Y')
# Out:
# Timestamp('2021-07-12 00:00:00')

# %%
s1 = '2022-05-15'


dtime1 = datetime.strptime(s1, '%Y-%m-%d')
S1 = datetime.isoformat(dtime1)


prior_date = dtime1 - timedelta(days = 20) ## 20 days prior to dtime1 (2022-05-15)
datetime.isoformat(prior_date)
# Out:
# '2022-04-25T00:00:00'

# %%
pd.to_datetime('12/7/21 21:00', format='%d/%m/%y %H:%M') - pd.to_timedelta(2, unit='D')
# Out:
# Timestamp('2021-07-10 21:00:00')

# %%
pd.to_datetime('12/7/21 21:00', format='%d/%m/%y %H:%M') + pd.to_timedelta(10, unit='W')
# Out:
# Timestamp('2021-09-20 21:00:00')

# %%
datetime.now() - timedelta(days = 7)
# Out:
# datetime.datetime(2022, 7, 27, 2, 6, 4, 989274)

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 8, 3, 2, 6, 44, 48624)

# %%
date.isoformat(date.today())
# Out:
# '2022-08-03'
